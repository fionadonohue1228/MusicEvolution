# %%
import pandas as pd
import numpy as np
import altair as alt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
spotify = pd.read_csv("15000_tracks_cleaned.csv")
spotify
# Out:
#        Unnamed: 0                track_id  \
# 0           12145  1dnVwpKHlDyTM8TJCEAOg5
# 1            7829  5jq2ArI1hhZ3wlJN8RijD3
# 2           11937  4piMfKVoPcY06x4hTLf9Pl
# 3           11969  0JiPUFfWlhT1SJ92eZ84GU
# 4           12027  6JRDBOkOxiOD32PBrFhf0O
# ...           ...                     ...
# 15819       15359  5aalFmrkQ4qQASL77hn5MG
# 15820       15536  5gWTCWosl7R6Ksw1swyuxz
# 15821       15537  4BSiq6NWxI2wqOXp28FTNf
# 15822       15526  3R2otHkcGwx78SdXFw5Dhl
# 15823        2384  46ZskDsXyj6SY4ILqw1XvK
#
#                                                  artists  \
# 0                                 Rashid Khan;Vidya Shah
# 1      Mohan;Ananya Bhat;Santhosh Venky;Sachin Basrur...
# 2                                        Rahul Deshpande
# 3                       Ajoy Chakrabarty;Parveen Sultana
# 4                Rashid Khan;Altamash Faridi;Antra Mitra
# ...                                                  ...
# 15819                             Charlie Puth;Jung Kook
# 15820                                            Ava Max
# 15821                                            Ava Max
# 15822                                            Ava Max
# 15823                           Oliver Tree;Robin Schulz
#
#                                               album_name  \
# 0                                                  Manto
# 1      KGF - Chapter 1 (Kannada) [Original Motion Pic...
# 2      Katyar Kaljat Ghusli (Original Motion Picture ...
# 3                                    Gadar Ek Prem Katha
# 4                                                Tu Mera
# ...                                                  ...
# 15819                            I'm Blue - Hits of 2022
# 15820                            Your Perfect Soundtrack
# 15821                                Baddest of Them All
# 15822                All That Really Matters - Just Hits
# 15823                                       Pop Hits Now
#
#                      track_name  popularity  duration_ms  explicit  \
# 0         Bol Ke Lab Azaad Hain          29       296591     False
# 1                 Dheera Dheera          50       222427     False
# 2                 Dil Ki Tapish          38       157238     False
# 3                Aan Milo Sajna          36       322533     False
# 4                       Tu Mera          32       290951     False
# ...                         ...         ...          ...       ...
# 15819            Left and Right           0       154486     False
# 15820  Maybe You're the Problem           0       190318     False
# 15821       Million Dollar Baby           0       184294     False
# 15822  Maybe You're the Problem           1       190318     False
# 15823                  Miss You           0       206000      True
#
#        danceability  energy  ...  liveness  valence    tempo  time_signature  \
# 0             0.381   0.410  ...    0.1140    0.225  172.377             4.0
# 1             0.483   0.886  ...    0.1140    0.235  124.795             4.0
# 2             0.576   0.671  ...    0.1580    0.474  116.122             4.0
# 3             0.367   0.836  ...    0.2160    0.503   68.144             4.0
# 4             0.428   0.580  ...    0.1200    0.478   83.429             4.0
# ...             ...     ...  ...       ...      ...      ...             ...
# 15819         0.881   0.592  ...    0.0901    0.719  101.058             4.0
# 15820         0.530   0.835  ...    0.0637    0.471  166.020             4.0
# 15821         0.667   0.858  ...    0.3250    0.641  133.039             4.0
# 15822         0.530   0.835  ...    0.0637    0.471  166.020             4.0
# 15823         0.587   0.742  ...    0.1460    0.199  145.007             4.0
#
#        track_genre  release_date  year  decade     era  is_hit
# 0        classical          0000     0       0     NaN   False
# 1          ambient          0000     0       0     NaN   False
# 2        classical          0000     0       0     NaN   False
# 3        classical          0000     0       0     NaN   False
# 4        classical          0000     0       0     NaN   False
# ...            ...           ...   ...     ...     ...     ...
# 15819        dance    2023-02-01  2023    2020  2010s+   False
# 15820        dance    2023-02-01  2023    2020  2010s+   False
# 15821        dance    2023-02-01  2023    2020  2010s+   False
# 15822        dance    2023-02-01  2023    2020  2010s+   False
# 15823  alternative    2023-02-01  2023    2020  2010s+   False
#
# [15824 rows x 26 columns]

# %%
spotify_rand = spotify.sample(n=50, random_state=42)

slider = alt.binding_range(min=0.05, max=1, step=0.05, name="Popularity:")
op_var = alt.param(value=0.5, bind=slider)

alt.Chart(spotify_rand).mark_bar().encode(
    x = alt.X('track_name:N', title='Track Name'),
    y = alt.Y('danceability:Q', title='Danceability'),
    color = alt.Color('popularity:Q', title='Popularity'),
    opacity = alt.OpacityValue(op_var)
).add_params(
    op_var
).properties(
    width=1000,
    height=500,
    title='Danceability Popularity by Track'
)
# Out:
# alt.Chart(...)

# %%
spotify[['duration_ms']].describe()
# Out:
#         duration_ms
# count  1.582400e+04
# mean   2.348558e+05
# std    1.357427e+05
# min    1.745300e+04
# 25%    1.707375e+05
# 50%    2.157165e+05
# 75%    2.710282e+05
# max    4.447520e+06

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'release_date', 'year', 'decade', 'era', 'is_hit'],
#       dtype='object')

# %%
## second visualization can be like a time chart of the duration of music over the time period, do a D3 visualization
